# %%
from data.data import temperature_df_full
import altair as alt
alt.data_transformers.enable('data_server')
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('data_server')

# %%
temperature_df_full
# Out:
#                      date  energy_appliances  energy_lights  pressure  \
# 0     2016-01-11 17:00:00                 60             30     733.5
# 1     2016-01-11 17:10:00                 60             30     733.6
# 2     2016-01-11 17:20:00                 50             30     733.7
# 3     2016-01-11 17:30:00                 50             40     733.8
# 4     2016-01-11 17:40:00                 60             40     733.9
# ...                   ...                ...            ...       ...
# 19730 2016-05-27 17:20:00                100              0     755.2
# 19731 2016-05-27 17:30:00                 90              0     755.2
# 19732 2016-05-27 17:40:00                270             10     755.2
# 19733 2016-05-27 17:50:00                420             10     755.2
# 19734 2016-05-27 18:00:00                430             10     755.2
#
#        windspeed  visibility   dewpoint day_of_week  hour_of_day    month  \
# 0       7.000000   63.000000   5.300000      Monday           17  January
# 1       6.666667   59.166667   5.200000      Monday           17  January
# 2       6.333333   55.333333   5.100000      Monday           17  January
# 3       6.000000   51.500000   5.000000      Monday           17  January
# 4       5.666667   47.666667   4.900000      Monday           17  January
# ...          ...         ...        ...         ...          ...      ...
# 19730   3.333333   23.666667  13.333333      Friday           17      May
# 19731   3.500000   24.500000  13.300000      Friday           17      May
# 19732   3.666667   25.333333  13.266667      Friday           17      May
# 19733   3.833333   26.166667  13.233333      Friday           17      May
# 19734   4.000000   27.000000  13.200000      Friday           18      May
#
#        workday time_of_day measurement_location  temperature   humidity  \
# 0      Weekday   Afternoon              kitchen    19.890000  47.596667
# 1      Weekday   Afternoon              kitchen    19.890000  46.693333
# 2      Weekday   Afternoon              kitchen    19.890000  46.300000
# 3      Weekday   Afternoon              kitchen    19.890000  46.066667
# 4      Weekday   Afternoon              kitchen    19.890000  46.333333
# ...        ...         ...                  ...          ...        ...
# 19730  Weekday   Afternoon              outside    22.733333  55.666667
# 19731  Weekday   Afternoon              outside    22.600000  56.000000
# 19732  Weekday   Afternoon              outside    22.466667  56.333333
# 19733  Weekday   Afternoon              outside    22.333333  56.666667
# 19734  Weekday     Evening              outside    22.200000  57.000000
#
#               floor         room_type    direction
# 0      Ground Floor  Functional Space  West Facing
# 1      Ground Floor  Functional Space  West Facing
# 2      Ground Floor  Functional Space  West Facing
# 3      Ground Floor  Functional Space  West Facing
# 4      Ground Floor  Functional Space  West Facing
# ...             ...               ...          ...
# 19730       Outside           Outside      Outside
# 19731       Outside           Outside      Outside
# 19732       Outside           Outside      Outside
# 19733       Outside           Outside      Outside
# 19734       Outside           Outside      Outside
#
# [197350 rows x 18 columns]

# %%
alt.Chart(temperature_df_full).mark_line().encode(
    x=alt.X('day_of_week',sort=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']),
    y='mean(temperature)',
    color="room_type"
).properties(height=200,width=200)
# Out:
# alt.Chart(...)

# %%
alt.Chart(temperature_df_full).mark_line().encode(
    x=alt.X('day_of_week',sort=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']),
    y='mean(humidity)',
    color="room_type"
).properties(height=200,width=200)
# Out:
# alt.Chart(...)
